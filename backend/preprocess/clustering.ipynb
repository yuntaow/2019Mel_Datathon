# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm


from PIL import Image, ImageDraw
import glob
import os
import matplotlib.pyplot as plt

import numpy as np
import scipy.misc as smp

import json
from datetime import datetime

from operator import add
import re

from sklearn.cluster import KMeans

# %%
# include functions 
# %run phase02-mask-generation/SugarUtils.py
# Out:
# ./tiles/tile-x7620-y7600.png
# ./geometries/geo-x7620-y7600.geojson
# ./mask/mask-x7620-y7600.png

# %%
# helper function

def get_mask_list(pixels):
    mask_list = []

    for x in range(0,512):
        for y in range(0,512):
            if pixels[y,x] == (0,0,0,255):
                mask_list.append((y,x))
    return mask_list

def get_timeseries_image_paths(tile_x, tile_y, band):
    path = f"./Phase02-DataDelivery/sugarcanetiles/{tile_x}-{tile_y}-{band}*.png"
    images = glob.glob(path)
    return images

# need to sort the band_img list
# sort the image path according to timeseries

def get_image_path_dict(band_img):
    image_path_dict = {}
    for bi in band_img:
        timestr = bi[-14:][:10]
        t = datetime.strptime(timestr, '%Y-%m-%d')
        image_path_dict[t] = bi
    return image_path_dict

# store sugacrane pixel to tci_list
def get_sugarcrane_region_from_tci(mask_list, band_pixels):
    tci_list = []

    for mask_ind in mask_list:
        y = mask_ind[0]
        x = mask_ind[1]

        tci_list.append(band_pixels[y,x])
    return tci_list

def get_tci_dict(image_path_dict, mask_list):
    tci_dict = {}
    cnt = 0
    for elem in sorted(image_path_dict.keys()):
    #     mask_list = 

        path = image_path_dict[elem]
        img = Image.open(path)
        band_pixels = img.load()

        tci_list = get_sugarcrane_region_from_tci(mask_list, band_pixels)
        tci_dict[cnt] = tci_list
        cnt += 1
    return tci_dict


def which_pixel_over_timeseries(i, tci_dict):
    red_list = []
    green_list = []
    blue_list = []
    for key, value in tci_dict.items():
        color = value[i]      # this is the ith pixel 
        red_list.append(color[0])
        green_list.append(color[1])
        blue_list.append(color[2])
    
    return {"red_list":red_list, "green_list":green_list,"blue_list":blue_list}

def which_pixel_over_timeseries_ndvi(i, dict1):
    res = []
    for key, value in dict1.items():
        num = value[i]      # this is the ith pixel 
        res.append(num)
    
    return res


# for identifying cloud
def is_white_pixel(r,g,b):
    if r >= 225 and g >= 225 and b >= 225:
        return True
    return False


# for identifying cloud
def is_blue_pixel(r,g,b):
    total = r + g + b
    if b > 180 and b / total > 0.35:
        return True
    return False

# this function needs more modifications !!!!!

def is_green_pixel(r,g,b):
    total = r + g + b
    if total == 0:
        return False
    if g / total > 0.33334:
        return True
    return False

# %%
mask_files = f"./Phase02-DataDelivery/masks/*.png"
mask_images = glob.glob(mask_files)

# get all the x, y positions of tiles from masks file name
xy_pair = []
for mask_img in mask_images:
    mask_list = re.findall(r'\d+', mask_img)
    xy_pair.append( (mask_list[1],mask_list[2]) )

# %%
# building all data dataframe 



# output csv for futher processing 

# 71 days in total 
# for each day, need to calculate total pixel number that are green - total sugacrane area 

tile_xy_dict = {}
for xy in tqdm( xy_pair ):
    # get mask png data
    tile_x, tile_y = xy[0], xy[1]
    mask_file_path = f"./Phase02-DataDelivery/masks/mask-x{tile_x}-y{tile_y}.png"
    img = Image.open(mask_file_path)
    pixels = img.load()
    
    mask_list = get_mask_list(pixels)

    # get tci_dict
    """
    band_img = get_timeseries_image_paths(tile_x, tile_y, "TCI")
    image_path_dict = get_image_path_dict(band_img)
    tci_dict = get_tci_dict(image_path_dict, mask_list)
    """
    
    # for ndvi analysis 
    band_img_RED = get_timeseries_image_paths(tile_x, tile_y, "B04")
    image_path_dict_RED = get_image_path_dict(band_img_RED)
    red_dict = get_tci_dict(image_path_dict_RED, mask_list)

    band_img_NIR = get_timeseries_image_paths(tile_x, tile_y, "B08")
    image_path_dict_NIR = get_image_path_dict(band_img_NIR)
    nir_dict = get_tci_dict(image_path_dict_NIR, mask_list)
    
    # get the rest of the band 
    band_img_BLUE = get_timeseries_image_paths(tile_x, tile_y, "B02")
    image_path_dict_BLUE = get_image_path_dict(band_img_BLUE)
    blue_dict = get_tci_dict(image_path_dict_BLUE, mask_list)
    
    band_img_GREEN = get_timeseries_image_paths(tile_x, tile_y, "B03")
    image_path_dict_GREEN = get_image_path_dict(band_img_GREEN)
    green_dict = get_tci_dict(image_path_dict_GREEN, mask_list)
    
    band_img_VRE1 = get_timeseries_image_paths(tile_x, tile_y, "B05")
    image_path_dict_VRE1 = get_image_path_dict(band_img_VRE1)
    vre1_dict = get_tci_dict(image_path_dict_VRE1, mask_list)
    
    band_img_VRE2 = get_timeseries_image_paths(tile_x, tile_y, "B06")
    image_path_dict_VRE2 = get_image_path_dict(band_img_VRE2)
    vre2_dict = get_tci_dict(image_path_dict_VRE2, mask_list)
    
    band_img_VRE3 = get_timeseries_image_paths(tile_x, tile_y, "B07")
    image_path_dict_VRE3 = get_image_path_dict(band_img_VRE3)
    vre3_dict = get_tci_dict(image_path_dict_VRE3, mask_list)
    
    tile_dict = {}

    for i in tqdm(range(0, len(mask_list))):
        # run over 184676 mask pixels 
        """
        color_dict = which_pixel_over_timeseries(i, tci_dict)
        tci_red_list = color_dict["red_list"]    # len = 71
        tci_green_list = color_dict["green_list"]
        tci_blue_list = color_dict["blue_list"]

        # if encounter cloud, then use adjacent color. (the previous image or the next image)
        cloud_list = []
        for j in range(0,71):
            r = tci_red_list[j]
            g = tci_green_list[j]
            b = tci_blue_list[j]
            if is_white_pixel(r,g,b) or is_blue_pixel(r,g,b):
                cloud_list.append(j)

        """
        
#         for key,value in color_dict.items():

        # calculate the ndvi value for that one particular pixel 
        nir_list = which_pixel_over_timeseries_ndvi(i, nir_dict)
        red_list = which_pixel_over_timeseries_ndvi(i, red_dict)
        blue_list = which_pixel_over_timeseries_ndvi(i, blue_dict)
        green_list = which_pixel_over_timeseries_ndvi(i, green_dict)
        vre1_list = which_pixel_over_timeseries_ndvi(i, vre1_dict)
        vre2_list = which_pixel_over_timeseries_ndvi(i, vre2_dict)
        vre3_list = which_pixel_over_timeseries_ndvi(i, vre3_dict)
        
        """
        for k in cloud_list:
            if k == 0:
                kk = k + 1
                while kk in cloud_list:
                    kk += 1
                    if kk == 71:
                        break
#                 value[k] = value[kk]
                nir_list[k] = nir_list[kk]
                red_list[k] = red_list[kk]
                blue_list[k] = blue_list[kk]
                green_list[k] = green_list[kk]
                vre1_list[k] = vre1_list[kk]
                vre2_list[k] = vre2_list[kk]
                vre3_list[k] = vre3_list[kk]
            else:
                kk = k - 1
                while kk in cloud_list:
                    kk -= 1
                    if kk == 0:
                        break
#                 value[k] = value[kk]
                nir_list[k] = nir_list[kk]
                red_list[k] = red_list[kk]
                blue_list[k] = blue_list[kk]
                green_list[k] = green_list[kk]
                vre1_list[k] = vre1_list[kk]
                vre2_list[k] = vre2_list[kk]
                vre3_list[k] = vre3_list[kk]
        """
        
        tile_dict[i] = { 
            "nir_list" : nir_list,
            "red_list" : red_list,
            "blue_list" : blue_list,
            "green_list" : green_list,
            "vre1_list" : vre1_list,
            "vre2_list" : vre2_list,
            "vre3_list" : vre3_list
        }
    
    dictkey = "x{}-y{}".format(tile_x,tile_y)
    tile_xy_dict[dictkey] = tile_dict
    break
# Out:
# HBox(children=(IntProgress(value=0, max=65), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=175950), HTML(value='')))

# %%
# tile_dict
# timeseries_list[37]  # 2018-05-26

res = []
for k, v in tqdm( tile_dict.items() ):   # a total of 175950 pixels
    l = []
    for kk, vv in v.items():    # a total of 7 faetures
        l.append(vv[37])
    res.append(l)
# Out:
# HBox(children=(IntProgress(value=0, max=175950), HTML(value='')))

# %%
df1 = pd.DataFrame(res, columns = ["nir", "red", "blue", "green", "vre1", "vre2", "vre3"])
df1.head()
# Out:
#     nir   red  blue  green  vre1  vre2  vre3
# 0  6146  1594  2512   2254  2318  4556  5816
# 1  5490  1692  2452   2192  2318  4556  5816
# 2  5546  1704  2484   2204  2446  4724  5690
# 3  5658  1694  2494   2218  2446  4724  5690
# 4  5558  1776  2462   2280  2544  4854  5914

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175950 entries, 0 to 175949
# Data columns (total 7 columns):
# nir      175950 non-null int64
# red      175950 non-null int64
# blue     175950 non-null int64
# green    175950 non-null int64
# vre1     175950 non-null int64
# vre2     175950 non-null int64
# vre3     175950 non-null int64
# dtypes: int64(7)
# memory usage: 9.4 MB

# %%
kmeans = KMeans(n_clusters=13, random_state=0, verbose=True, n_jobs=-1, tol=1e-5, max_iter=900)
X = df1.values
kmeans.fit(X)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 362160018931.89435
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 326204502454.5248
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 318745604133.8712
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 316257378844.33264
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 315187893353.081
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 314607866652.5325
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 314213198696.60156
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 313875888672.4602
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 313562164397.4626
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 313259682193.61694
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 312962924563.519
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 312694451523.19226
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 312432348893.95575
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 312186954990.6129
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 311960857128.1313
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 311749416844.9461
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 311529490476.9437
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 311313831099.5577
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 311106273422.42664
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 310904800733.0338
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 310700706867.4035
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 310488963887.6559
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 310290006669.40704
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 310093737057.5276
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 309896372820.6273
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 309699531732.6921
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 309488765164.9087
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 309251170828.11865
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 309010282719.2858
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 308757136556.0198
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 308495743435.5895
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 308213182059.4203
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 307932022878.6017
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 307652118738.99725
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 307384261940.5139
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 307133304020.2188
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 306898173848.33777
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 306656042607.33527
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 306418316477.0203
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 306195145853.00916
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 305980283482.01385
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 305762814457.6103
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 305552416935.5443
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 305369497756.5312
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 305201198415.0658
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 300351403027.88184
# start iteration
# done sorting
# end inner loop
# ...
# start iteration
# done sorting
# end inner loop
# Iteration 145, inertia 300141795278.3861
# start iteration
# done sorting
# end inner loop
# Iteration 146, inertia 300121237289.4827
# start iteration
# done sorting
# end inner loop
# Iteration 147, inertia 300102075189.5891
# start iteration
# done sorting
# end inner loop
# Iteration 148, inertia 300083569291.3203
# start iteration
# done sorting
# end inner loop
# Iteration 149, inertia 300066370469.11804
# start iteration
# done sorting
# end inner loop
# Iteration 150, inertia 300050949721.7545
# start iteration
# done sorting
# end inner loop
# Iteration 151, inertia 300036467065.4583
# start iteration
# done sorting
# end inner loop
# Iteration 152, inertia 300021842697.3354
# start iteration
# done sorting
# end inner loop
# Iteration 153, inertia 300009937302.2474
# start iteration
# done sorting
# end inner loop
# Iteration 154, inertia 299998272436.8502
# start iteration
# done sorting
# end inner loop
# Iteration 155, inertia 299987195008.76025
# start iteration
# done sorting
# end inner loop
# Iteration 156, inertia 299976033491.7533
# start iteration
# done sorting
# end inner loop
# Iteration 157, inertia 299964363611.26373
# start iteration
# done sorting
# end inner loop
# Iteration 158, inertia 299951357474.3679
# start iteration
# done sorting
# end inner loop
# Iteration 159, inertia 299938865509.613
# start iteration
# done sorting
# end inner loop
# Iteration 160, inertia 299926173328.3096
# start iteration
# done sorting
# end inner loop
# Iteration 161, inertia 299913454758.91614
# start iteration
# done sorting
# end inner loop
# Iteration 162, inertia 299902520336.46277
# start iteration
# done sorting
# end inner loop
# Iteration 163, inertia 299890274520.3959
# start iteration
# done sorting
# end inner loop
# Iteration 164, inertia 299878276962.394
# start iteration
# done sorting
# end inner loop
# Iteration 165, inertia 299867544246.3751
# start iteration
# done sorting
# end inner loop
# Iteration 166, inertia 299857063094.192
# start iteration
# done sorting
# end inner loop
# Iteration 167, inertia 299847227642.3542
# start iteration
# done sorting
# end inner loop
# Iteration 168, inertia 299837475596.13464
# start iteration
# done sorting
# end inner loop
# Iteration 169, inertia 299829280563.1048
# start iteration
# done sorting
# end inner loop
# Iteration 170, inertia 299822803304.894
# start iteration
# done sorting
# end inner loop
# Iteration 171, inertia 299816902897.9553
# start iteration
# done sorting
# end inner loop
# Iteration 172, inertia 299811279781.0552
# start iteration
# done sorting
# end inner loop
# Iteration 173, inertia 299805607915.10693
# start iteration
# done sorting
# end inner loop
# Iteration 174, inertia 299801340586.9785
# start iteration
# done sorting
# end inner loop
# Iteration 175, inertia 299797017764.32513
# start iteration
# done sorting
# end inner loop
# Iteration 176, inertia 299792760757.4513
# start iteration
# done sorting
# end inner loop
# Iteration 177, inertia 299788895177.20605
# start iteration
# done sorting
# end inner loop
# Iteration 178, inertia 299785172125.49896
# start iteration
# done sorting
# end inner loop
# Iteration 179, inertia 299781243864.9708
# start iteration
# done sorting
# end inner loop
# Iteration 180, inertia 299777179128.2549
# start iteration
# done sorting
# end inner loop
# Iteration 181, inertia 299773480977.3829
# start iteration
# done sorting
# end inner loop
# Iteration 182, inertia 299769598884.00287
# start iteration
# done sorting
# end inner loop
# Iteration 183, inertia 299765434272.84436
# start iteration
# done sorting
# end inner loop
# Iteration 184, inertia 299761467960.3887
# start iteration
# done sorting
# end inner loop
# Iteration 185, inertia 299757339690.612
# start iteration
# done sorting
# end inner loop
# Iteration 186, inertia 299754088510.5625
# start iteration
# done sorting
# end inner loop
# Iteration 187, inertia 299751290480.8835
# start iteration
# done sorting
# end inner loop
# Iteration 188, inertia 299749205696.4665
# start iteration
# done sorting
# end inner loop
# Iteration 189, inertia 299747167091.5478
# start iteration
# done sorting
# end inner loop
# Iteration 190, inertia 299745353735.9333
# start iteration
# done sorting
# end inner loop
# Iteration 191, inertia 299743936353.27136
# start iteration
# done sorting
# end inner loop
# Iteration 192, inertia 299742669330.7836
# start iteration
# done sorting
# end inner loop
# Iteration 193, inertia 299741426155.856
# start iteration
# done sorting
# end inner loop
# Iteration 194, inertia 299739962259.54553
# start iteration
# done sorting
# end inner loop
# Iteration 195, inertia 299738763381.24817
# start iteration
# done sorting
# end inner loop
# Iteration 196, inertia 299737881262.248
# start iteration
# done sorting
# end inner loop
# Iteration 197, inertia 299737091516.294
# start iteration
# done sorting
# end inner loop
# Iteration 198, inertia 299736275268.6905
# start iteration
# done sorting
# end inner loop
# Iteration 199, inertia 299735507806.9608
# start iteration
# done sorting
# end inner loop
# Iteration 200, inertia 299734611677.7364
# start iteration
# done sorting
# end inner loop
# Iteration 201, inertia 299733405920.2995
# start iteration
# done sorting
# end inner loop
# Iteration 202, inertia 299732208847.86426
# start iteration
# done sorting
# end inner loop
# Iteration 203, inertia 299731127682.9208
# start iteration
# done sorting
# end inner loop
# Iteration 204, inertia 299730106857.5481
# start iteration
# done sorting
# end inner loop
# Iteration 205, inertia 299729294994.97955
# start iteration
# done sorting
# end inner loop
# Iteration 206, inertia 299728559746.9072
# start iteration
# done sorting
# end inner loop
# Iteration 207, inertia 299727824010.8036
# start iteration
# done sorting
# end inner loop
# Iteration 208, inertia 299727196886.2691
# start iteration
# done sorting
# end inner loop
# Iteration 209, inertia 299726654138.68164
# start iteration
# done sorting
# end inner loop
# Iteration 210, inertia 299726137054.8319
# start iteration
# done sorting
# end inner loop
# Iteration 211, inertia 299725645134.54614
# start iteration
# done sorting
# end inner loop
# Iteration 212, inertia 299725209802.0325
# start iteration
# done sorting
# end inner loop
# Iteration 213, inertia 299724760584.19183
# start iteration
# done sorting
# end inner loop
# Iteration 214, inertia 299724303793.0097
# start iteration
# done sorting
# end inner loop
# Iteration 215, inertia 299723567054.5876
# start iteration
# done sorting
# end inner loop
# Iteration 216, inertia 299723012168.7444
# start iteration
# done sorting
# end inner loop
# Iteration 217, inertia 299722619807.4913
# center shift 1.140244e+01 within tolerance 1.631857e+02
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 355246287937.8623
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 344700731593.09735
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 341206113008.52374
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 335598315648.58234
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 327687733739.58545
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 322083641769.8177
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 319207351275.2125
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 317623378918.76965
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 316548010186.64325
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 315603629204.55194
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 314578777210.2577
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 313163042391.2384
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 310983417508.57874
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 308495549277.5256
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 306701383553.3258
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 305685853815.5473
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 305131373087.8812
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 304769451578.4752
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 304485220450.6768
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 304248571616.27875
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 304025582393.9314
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 303816581592.22754
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 303621143874.77045
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 303439541842.8023
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 303270176609.26776
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 303111853009.0661
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 302969226035.33386
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 302833149505.5776
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 302690787943.65173
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 302554487215.3457
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 302427858805.38574
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 302313271679.15594
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 302206673074.7258
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 302114090738.897
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 302030847844.1795
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 301948116468.4853
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 301860348093.75793
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 301784800419.4658
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 301713360075.4031
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 301640596498.2435
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 301570920696.0458
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 301502855987.289
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 301435361317.1347
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 301372312213.15576
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 301307140355.4529
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 301241503165.7091
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 301174498955.3578
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 301116315657.59454
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 301063370361.9496
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 301009813639.749
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 300959290489.9869
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 300907598183.4228
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 300856467386.27844
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 300806919746.7171
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 300761325499.1584
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 300718737341.9288
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 300675940650.458
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 300635177223.5137
# start iteration
# done sorting
# end inner loop
# Iteration 58, inertia 300595563495.9521
# start iteration
# done sorting
# end inner loop
# Iteration 59, inertia 300558988698.2808
# start iteration
# done sorting
# end inner loop
# Iteration 60, inertia 300524925174.9047
# start iteration
# done sorting
# end inner loop
# Iteration 61, inertia 300488385744.0705
# start iteration
# done sorting
# end inner loop
# Iteration 62, inertia 300450861832.3274
# start iteration
# done sorting
# end inner loop
# Iteration 63, inertia 300416265970.48865
# start iteration
# done sorting
# end inner loop
# Iteration 64, inertia 300384354977.8804
# start iteration
# done sorting
# end inner loop
# Iteration 65, inertia 300352639095.3382
# start iteration
# done sorting
# end inner loop
# Iteration 66, inertia 300321193515.43506
# start iteration
# done sorting
# end inner loop
# Iteration 67, inertia 300289945978.5508
# start iteration
# done sorting
# end inner loop
# Iteration 68, inertia 300258066282.032
# start iteration
# done sorting
# end inner loop
# Iteration 69, inertia 300228610882.601
# start iteration
# done sorting
# end inner loop
# Iteration 70, inertia 300203529886.3033
# start iteration
# done sorting
# end inner loop
# Iteration 71, inertia 300177375123.9571
# start iteration
# done sorting
# end inner loop
# Iteration 72, inertia 300152734198.2666
# start iteration
# done sorting
# end inner loop
# Iteration 73, inertia 300127803717.1654
# start iteration
# done sorting
# end inner loop
# Iteration 74, inertia 300100443252.8321
# start iteration
# done sorting
# end inner loop
# Iteration 75, inertia 300075281754.7053
# start iteration
# done sorting
# end inner loop
# Iteration 76, inertia 300049572611.187
# start iteration
# done sorting
# end inner loop
# Iteration 77, inertia 300022628226.9364
# start iteration
# done sorting
# end inner loop
# Iteration 78, inertia 299997806605.0953
# start iteration
# done sorting
# end inner loop
# Iteration 79, inertia 299971730558.9002
# start iteration
# done sorting
# end inner loop
# Iteration 80, inertia 299949009247.7239
# start iteration
# done sorting
# end inner loop
# Iteration 81, inertia 299926509620.22614
# start iteration
# done sorting
# end inner loop
# Iteration 82, inertia 299907711775.35486
# start iteration
# done sorting
# end inner loop
# Iteration 83, inertia 299891452668.93616
# start iteration
# done sorting
# end inner loop
# Iteration 84, inertia 299874582250.59546
# start iteration
# done sorting
# end inner loop
# Iteration 85, inertia 299858939544.29767
# start iteration
# done sorting
# end inner loop
# Iteration 86, inertia 299843407181.1474
# start iteration
# done sorting
# end inner loop
# Iteration 87, inertia 299829897914.4719
# start iteration
# done sorting
# end inner loop
# Iteration 88, inertia 299819835372.4661
# start iteration
# done sorting
# end inner loop
# Iteration 89, inertia 299811445655.5189
# start iteration
# done sorting
# end inner loop
# Iteration 90, inertia 299803379450.4605
# start iteration
# done sorting
# end inner loop
# Iteration 91, inertia 299795442897.4696
# start iteration
# done sorting
# end inner loop
# Iteration 92, inertia 299787352513.0066
# start iteration
# done sorting
# end inner loop
# Iteration 93, inertia 299780601625.01013
# start iteration
# done sorting
# end inner loop
# Iteration 94, inertia 299775111005.5383
# start iteration
# done sorting
# end inner loop
# Iteration 95, inertia 299769963056.06085
# start iteration
# done sorting
# end inner loop
# Iteration 96, inertia 299764962579.52527
# start iteration
# done sorting
# end inner loop
# Iteration 97, inertia 299759921398.9474
# start iteration
# done sorting
# end inner loop
# Iteration 98, inertia 299755326258.65875
# start iteration
# done sorting
# end inner loop
# Iteration 99, inertia 299751556429.35846
# start iteration
# done sorting
# end inner loop
# Iteration 100, inertia 299748923414.6279
# start iteration
# done sorting
# end inner loop
# Iteration 101, inertia 299746518824.8992
# start iteration
# done sorting
# end inner loop
# Iteration 102, inertia 299744348186.02826
# start iteration
# done sorting
# end inner loop
# Iteration 103, inertia 299742181810.59
# start iteration
# done sorting
# end inner loop
# Iteration 104, inertia 299740724570.9276
# start iteration
# done sorting
# end inner loop
# Iteration 105, inertia 299739548273.4353
# start iteration
# done sorting
# end inner loop
# Iteration 106, inertia 299738664267.2658
# start iteration
# done sorting
# end inner loop
# Iteration 107, inertia 299737944005.3643
# start iteration
# done sorting
# end inner loop
# Iteration 108, inertia 299737338448.83453
# start iteration
# done sorting
# end inner loop
# Iteration 109, inertia 299736743348.38916
# start iteration
# done sorting
# end inner loop
# Iteration 110, inertia 299736162240.89014
# start iteration
# done sorting
# end inner loop
# Iteration 111, inertia 299735666343.9967
# center shift 1.251284e+01 within tolerance 1.631857e+02
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=900,
#     n_clusters=13, n_init=10, n_jobs=-1, precompute_distances='auto',
#     random_state=0, tol=1e-05, verbose=True)

# %%
# len(mask_list)
type_y = kmeans.labels_
len(type_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7538ab935a1> in <module>
#       1 # len(mask_list)
# ----> 2 type_y = kmeans.labels_
#       3 len(type_y)
#
# NameError: name 'kmeans' is not defined

# %%
mask_list[0]
# Out:
# (0, 0)

# %%
d1 = {}
cnt = 0
for ml in tqdm(mask_list):
    x = ml[0]
    y = ml[1]
    d1["x{}-y{}".format(x,y)] = type_y[cnt]
    cnt+=1
# Out:
# HBox(children=(IntProgress(value=0, max=175950), HTML(value='')))

# %%
xy_pair[0]
# Out:
# ('6144', '5120')

# %%
# draw color change over timeseries

color_type = {
    "0": (255,0,0),
    "1": (255,255,0),
    "2": (255,0,255),
    "3": (0,0,255),
    "4": (0,255,255),
    "5": (0,255,0),
    "6": (255,145,0),
    "7": (255,255,255),
    "8": (150,150,150),
    "9": (111,1,1),
    "10": (74,1,111),
    "11": (229,204,255),
    "12": (255,229,204)
}

data = np.zeros( (512,512,3), dtype=np.uint8 )

# data[512,512] = (254,0,0)       # Makes the middle pixel red
# data[512,513] = (0,0,255)       # Makes the next pixel blue

for x in range(0,512):
    for y in range(0,512):
            k = "x{}-y{}".format(x,y)
            if k in d1:
                s_type = d1[k]
                data[y,x] = color_type[str(s_type)]
            else:
                data[y,x] = (0, 0, 0)

img = smp.toimage( data )
img.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
